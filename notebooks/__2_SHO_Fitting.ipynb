# %% [markdown]
# # SHO Fitting
#
# This notebook completes the SHO fitting using the conventional algorithms in Pycroscopy.

# %% [markdown]
# ## Import Packages

# %%
# import sys

# sys.path.append("../../")
# sys.path.append('../../src')
# sys.path.append('/home/julian/BEPiezo-Learn/src')

# %%
# # For the notebook to work you must have m3_learning installed
# # pip install m3_learning
# %load_ext autoreload
# %autoreload 2

from m3util.viz.printing import printer
from m3util.viz.style import set_style
from m3util.ml.rand import set_seeds
from m3util.util.IO import download_and_unzip
from belearn.dataset.dataset import BE_Dataset
from belearn.viz.viz import Viz

import numpy as np

# from m3_learning.be.dataset import BE_Dataset
printing = printer(basepath = './Figures/')

set_style("printing")
set_seeds(seed=42)
# Out:
# /tmp/ipykernel_2457802/1313777072.py:16: DeprecationWarning: The 'printer' class/function has been renamed to 'Printer'. Please update your code.
#   printing = printer(basepath = './Figures/')
# printing set for seaborn
# Pytorch seed was set to 42
# Numpy seed was set to 42
# 2025-05-23 18:12:05.134567: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748038325.184271 2457802 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748038325.198128 2457802 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748038325.304222 2457802 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748038325.304242 2457802 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748038325.304246 2457802 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748038325.304248 2457802 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-23 18:12:05.313583: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tensorflow seed was set to 42

# %% [markdown]
# ## Loading data for SHO fitting

# %%
# Download the data file from Zenodo
url = 'https://zenodo.org/record/7774788/files/PZT_2080_raw_data.h5?download=1'

# Specify the filename and the path to save the file
# filename = 'data_raw.h5'
filename = 'data_raw.h5'
save_path = './Data'

# download the file
download_and_unzip(filename, url, save_path)
# Out:
# Using files already downloaded

# %%
data_path = save_path + '/' + filename

# instantiate the dataset object
dataset = BE_Dataset(data_path)

# print the contents of the file
dataset.print_be_tree
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ Bin_FFT
#     ├ Bin_Frequencies
#     ├ Bin_Indices
#     ├ Bin_Step
#     ├ Bin_Wfm_Type
#     ├ Excitation_Waveform
#     ├ Noise_Floor
#     ├ Noisy_Data_1
#     ├ Noisy_Data_2
#     ├ Noisy_Data_3
#     ├ Noisy_Data_4
#     ├ Noisy_Data_5
#     ├ Noisy_Data_6
#     ├ Noisy_Data_7
#     ├ Noisy_Data_8
#     ├ Position_Indices
#     ├ Position_Values
#     ├ Raw_Data
#     ├ Spatially_Averaged_Plot_Group_000
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spatially_Averaged_Plot_Group_001
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ UDVS
#     ├ UDVS_Indices
# Datasets and data groups within the file:
# ------------------------------------
# /
# /Measurement_000
# /Measurement_000/Channel_000
# /Measurement_000/Channel_000/Bin_FFT
# /Measurement_000/Channel_000/Bin_Frequencies
# /Measurement_000/Channel_000/Bin_Indices
# /Measurement_000/Channel_000/Bin_Step
# /Measurement_000/Channel_000/Bin_Wfm_Type
# /Measurement_000/Channel_000/Excitation_Waveform
# /Measurement_000/Channel_000/Noise_Floor
# /Measurement_000/Channel_000/Noisy_Data_1
# /Measurement_000/Channel_000/Noisy_Data_2
# /Measurement_000/Channel_000/Noisy_Data_3
# /Measurement_000/Channel_000/Noisy_Data_4
# /Measurement_000/Channel_000/Noisy_Data_5
# /Measurement_000/Channel_000/Noisy_Data_6
# /Measurement_000/Channel_000/Noisy_Data_7
# /Measurement_000/Channel_000/Noisy_Data_8
# /Measurement_000/Channel_000/Position_Indices
# /Measurement_000/Channel_000/Position_Values
# /Measurement_000/Channel_000/Raw_Data
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Step_Averaged_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Step_Averaged_Response
# /Measurement_000/Channel_000/Spectroscopic_Indices
# /Measurement_000/Channel_000/Spectroscopic_Values
# /Measurement_000/Channel_000/UDVS
# /Measurement_000/Channel_000/UDVS_Indices
#
# The main dataset:
# ------------------------------------
# <HDF5 file "data_raw.h5" (mode r+)>
#
# The ancillary datasets:
# ------------------------------------
# <HDF5 dataset "Position_Indices": shape (3600, 2), type "<u4">
# <HDF5 dataset "Position_Values": shape (3600, 2), type "<f4">
# <HDF5 dataset "Spectroscopic_Indices": shape (4, 63360), type "<u4">
# <HDF5 dataset "Spectroscopic_Values": shape (4, 63360), type "<f4">
#
# Metadata or attributes in a data group
# ------------------------------------
# BE_actual_duration_[s] : 0.004
# BE_amplitude_[V] : 1
# BE_auto_smoothing : auto smoothing on
# BE_band_edge_smoothing_[s] : 4832.1
# BE_band_edge_trim : 0.094742
# BE_band_width_[Hz] : 200000
# BE_bins_per_band : 0
# BE_center_frequency_[Hz] : 1310000
# BE_desired_duration_[s] : 0.004
# BE_phase_content : chirp-sinc hybrid
# BE_phase_variation : 1
# BE_points_per_BE_wave : 0
# BE_repeats : 4
# FORC_V_high1_[V] : 1
# FORC_V_high2_[V] : 10
# FORC_V_low1_[V] : -1
# FORC_V_low2_[V] : -10
# FORC_num_of_FORC_cycles : 1
# FORC_num_of_FORC_repeats : 1
# File_MDAQ_version : MDAQ_VS_090915_01
# File_date_and_time : 18-Sep-2015 18:32:14
# File_file_name : SP128_NSO
# File_file_path : C:\Users\Asylum User\Documents\Users\Agar\SP128_NSO\
# File_file_suffix : 99
# IO_AO_amplifier : 10
# IO_AO_range_[V] : +/- 10
# IO_Analog_Input_1 : +/- .1V, FFT
# IO_Analog_Input_2 : off
# IO_Analog_Input_3 : off
# IO_Analog_Input_4 : off
# IO_DAQ_platform : NI 6115
# IO_rate_[Hz] : 4000000
# VS_amplitude_[V] : 16
# VS_cycle_fraction : full
# VS_cycle_phase_shift : 0
# VS_measure_in_field_loops : in and out-of-field
# VS_mode : DC modulation mode
# VS_number_of_cycles : 2
# VS_offset_[V] : 0
# VS_read_voltage_[V] : 0
# VS_set_pulse_amplitude[V] : 0
# VS_set_pulse_duration[s] : 0.002
# VS_step_edge_smoothing_[s] : 0.001
# VS_steps_per_full_cycle : 96
# data_type : BEPSData
# grid_/single : grid
# grid_contact_set_point_[V] : 1
# grid_current_col : 1
# grid_current_row : 1
# grid_cycle_time_[s] : 10
# grid_measuring : 0
# grid_moving : 0
# grid_num_cols : 60
# grid_num_rows : 60
# grid_settle_time_[s] : 0.15
# grid_time_remaining_[h;m;s] : 10
# grid_total_time_[h;m;s] : 10
# grid_transit_set_point_[V] : 0.1
# grid_transit_time_[s] : 0.15
# num_bins : 165
# num_pix : 3600
# num_udvs_steps : 384

# %% [markdown]
# ## Visualize Raw Data
#
# ### Raw Cantilever Response

# %%
# insatiate the visualization object
image_scalebar = [2000, 500, "nm", "br"]

BE_viz = Viz(dataset, printing, verbose=True, 
             SHO_ranges = [(0,1.5e-4), (1.31e6, 1.33e6), (-300, 300), (-np.pi, np.pi)], 
             image_scalebar = image_scalebar)

# %%
prediction = {"resampled": False,
              "label": "Raw"}

BE_viz.raw_data_comparison(prediction, filename="Figure_2_1_raw_cantilever_response")
# Out:
# /home/jca92/M3Learning-Util/src/m3util/viz/layout.py:256: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(wspace=wspace, hspace=hspace)
# ***
# pixel:  130
# voltage_step:  149
# ***
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 prediction = {"resampled": False,
#       2               "label": "Raw"}
# ----> 4 BE_viz.raw_data_comparison(prediction, filename="Figure_2_1_raw_cantilever_response")
#
# File ~/josh-bepfm/BEPiezo-Learn/src/belearn/util/wrappers.py:48, in context_manager_decorator.<locals>.wrapper(self, *args, **kwargs)
#      45 @wraps(func)
#      46 def wrapper(self, *args, **kwargs):
#      47     with temporary_state(self,**kwargs.get('true', {})):  # Use the true state if provided
# ---> 48         return func(self, *args, **kwargs)
#
# File ~/josh-bepfm/BEPiezo-Learn/src/belearn/viz/viz.py:703, in Viz.raw_data_comparison(self, true, predict, filename, pixel, voltage_step, legend, **kwargs)
#     700 print("voltage_step: ", voltage_step)
#     701 print("***")
# --> 703 ax_mag, ax_phase = self.plot_twin_axis(
#     704     axs[0],
#     705     true,
#     706     predict,
#     707     pixel,
#     708     voltage_step,
#     709     fig=fig,
#     710     raw_format="magnitude spectrum",
#     711     ax1_true_color=color_palette["true_mag"],
#     712     ax2_true_color=color_palette["true_phase"],
#     713     ax1_predict_color=color_palette["predict_mag"],
#     714     ax2_predict_color=color_palette["predict_phase"],
#     715     ax1_predict_marker="o",
#     716     ax2_predict_marker="o",
#     717     marker="s",
#     718     ax1_true_label=true["label"] + " Amplitude",
#     719     ax2_true_label=true["label"] + " Phase",
#     720     ax1_predict_label=predict["label"] + " Amplitude"
#     721     if predict is not None
#     722     else None,
#     723     ax2_predict_label=predict["label"] + " Phase"
#     724     if predict is not None
#     725     else None,
#     726     x_label="Frequency (Hz)",
#     727     y1_label="Amplitude (Arb. U.)",
#     728     y2_label="Phase (deg)",
#     729     **kwargs,
#     730 )
#     732 ax_real, ax_imag = self.plot_twin_axis(
#     733     axs[1],
#     734     true,
#    (...)    758     **kwargs,
#     759 )
#     761 # ax_mag, ax_phase = self.plot_magnitude_spectrum(
#     762 #     axs[0], true, predict, pixel, voltage_step, fig=fig, **kwargs
#     763 # )
#    (...)    769 # Adjust the format of the tick labels and box aspect for all axes
#     770 # axes = [ax_mag, ax_real, ax_phase, ax_imag]
#
# File ~/josh-bepfm/BEPiezo-Learn/src/belearn/util/wrappers.py:48, in context_manager_decorator.<locals>.wrapper(self, *args, **kwargs)
#      45 @wraps(func)
#      46 def wrapper(self, *args, **kwargs):
#      47     with temporary_state(self,**kwargs.get('true', {})):  # Use the true state if provided
# ---> 48         return func(self, *args, **kwargs)
#
# File ~/josh-bepfm/BEPiezo-Learn/src/belearn/viz/viz.py:245, in Viz.plot_twin_axis(self, ax1, true, predict, pixel, voltage_step, add_arrows, **kwargs)
#     239     self.raw_format = kwargs["raw_format"]
#     241 # Get the raw spectral data for the selected pixel and voltage step
#     242 # with State.temporary_state(self, **true):
#     243 # JGoddy added scaled on May 14 without testing it
#     244 # if 'scaled' should always be False here, then remove it from the function call
# --> 245 data, x = self.raw_spectra(pixel, voltage_step, frequency=True, scaled = self.scaled)
#     247 # Get the valid parameters for the plot method
#     248 plot_params = mlines.Line2D([], []).properties().keys()
#
# File ~/josh-bepfm/BEPiezo-Learn/src/belearn/util/wrappers.py:48, in context_manager_decorator.<locals>.wrapper(self, *args, **kwargs)
#      45 @wraps(func)
#      46 def wrapper(self, *args, **kwargs):
#      47     with temporary_state(self,**kwargs.get('true', {})):  # Use the true state if provided
# ---> 48         return func(self, *args, **kwargs)
#
# File ~/josh-bepfm/BEPiezo-Learn/src/belearn/dataset/state.py:370, in State.raw_spectra(self, pixel, voltage_step, fit_results, frequency, **kwargs)
#     364         data = self.raw_data_reshaped[self.dataset_name][pixel][voltage_step]
#     366         #data = self.raw_data_resampled(
#     367         #    pixel=pixel, voltage_step=voltage_step
#     368         #)
#     369     else:
# --> 370         data = self.raw_data(pixel=pixel, voltage_step=voltage_step)
#     371 else:
#     372     # Process the fit results to obtain raw spectra
#     373     params_shape = fit_results.shape
#
# File ~/josh-bepfm/BEPiezo-Learn/src/belearn/dataset/preprocessing.py:325, in Preprocessing.raw_data(self, pixel, voltage_step)
#     317 # JGoddy commented out the h5py file opening because
#     318 # h5_f was not being used in the code
#     319
#     320 # Open the HDF5 file in read+write mode
#     321 # with h5py.File(self.file, "r+") as h5_f:
#     322     # Extract data based on provided pixel and voltage_step indices
#     323 if pixel is not None and voltage_step is not None:
#     324     # Specific pixel and voltage_step provided
# --> 325     return self.raw_data_reshaped[self.dataset_name][[pixel], :, :][
#     326         :, [voltage_step], :
#     327     ]
#     328 else:
#     329     # Return the entire dataset if pixel or voltage_step is not specified
#     330     return self.raw_data_reshaped[self.dataset_name][:]
#
# AttributeError: 'Viz' object has no attribute 'raw_data_reshaped'

# %% [markdown]
# **Figure 2.1** Raw cantilever response. a) magnitude spectrum and Phase, b) real and imaginary parts of the complex spectrum.

# %% [markdown]
# ### Band-Excitation Experiments

# %%
BE_viz.raw_be(dataset, filename="Figure_2_2_raw_be_experiment")

# %% [markdown]
# **Figure 2.2** Band-Excitation Experiments. a) raw drive amplitude applied to the tip, b) energy of the waveform in the frequency domain, c) DC voltage applied to switch the sample, inset shows a zoomed in view of the switching waveform where measurements are made in the on and off state. d) raw cantilever response magnitude and phase, e) real and imaginary parts of the complex spectrum.

# %% [markdown]
# ## SHO Fitting
# **Note**: this code takes around 15 minutes to execute
#
# If you downloaded the SHO fit data, or ran notebook 1 you do not need to fit the data again.
#
# You can skip to the next section.
#
# If you would like to run this code block please change the Fit_SHO flag to `True`

# %%
Fit_SHO = False

if Fit_SHO: 

    # # computes the SHO fit for the data in the file
    dataset.SHO_Fitter(force = True)
    
    # instantiate the dataset object
    # good to reinstantiate the dataset object after fitting
    dataset = BE_Dataset(data_path)

# %% [markdown]
# ### Views the Distribution of the Least Squares Fitting (LSQF) results
#
# It is good to view the distributions and standardize the phase shift. The phase shift is rotated around the unit circle such that the peaks are at $-\pi/2$ and $\pi/2$

# %%
dataset.LSQF_phase_shift = 0

BE_viz.SHO_hist(dataset.SHO_fit_results(),
                      filename="Figure_2_3_Original_LSQF_Histograms")

# %% [markdown]
# **Figure 2.3** Distribution of the Least Squares Fitting (LSQF) results of the unmodified data. a) Distribution of the amplitude, b) Distribution of the resonance frequency, c) distribution of the quality factor, d) distribution of the resonance frequency.

# %%
dataset.LSQF_phase_shift = np.pi/2

BE_viz.SHO_hist(dataset.SHO_fit_results(),
                      filename="Figure_4_Phase_Shifted_LSQF_Histograms")

# %% [markdown]
# **Figure 2.4** Distribution of the Least Squares Fitting (LSQF) results of the normalized data. a) Distribution of the amplitude, b) distribution of the resonance frequency, c) distribution of the quality factor, d) distribution of the resonance frequency.

# %% [markdown]
# ### Plots the SHO Fit Results

# %%
BE_viz.dataset.measurement_state = 'on'

BE_viz.SHO_loops(filename="Figure_2_5_Single_Pixel_Loops")

# %% [markdown]
# **Figure 2_5.** Example switching loops obtained for the amplitude, resonance frequency, quality factor, and phase.

# %% [markdown]
# ## SHO Switching Movies

# %%
BE_viz.SHO_fit_movie_images(noise = 0, 
                            scalebar_= True, 
                            basepath = "Movies/SHO_LSQF_",  
                            filename="SHO_LSQF",
                            phase_shift = [np.pi/2])
