# %% [markdown]
# # 1 Generate Noisy Data and Fitting
#
# This is an optional notebook that is used to generate noisy data for the manuscript. We note that we provide the output of this notebook directly as a download.
#
# This notebook is used to generate and fit all the data required for the paper. We will generate data for the following noise cases:
#
# 1, 2, 3, 4, 5, 6, 7, where each case corresponds to a different noise level.

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

from m3util.util.IO import download_and_unzip

from belearn.dataset.dataset import BE_Dataset


import numpy as np

# %% [markdown]
# ## Loading data for SHO fitting

# %%
# Download the data file from Zenodo
url = 'https://zenodo.org/record/7774788/files/PZT_2080_raw_data.h5?download=1'

# Specify the filename and the path to save the file
filename = '/data_raw7.h5'
save_path = './Data'

# download the file
download_and_unzip(filename, url, save_path)
# Out:
# downloading data
# ...100%, 1663 MB, 15032 KB/s, 113 seconds passed

# %%
data_path = save_path + '/' + filename

# instantiate the dataset object
dataset = BE_Dataset(data_path)

# print the contents of the file
dataset.print_be_tree
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ Bin_FFT
#     ├ Bin_Frequencies
#     ├ Bin_Indices
#     ├ Bin_Step
#     ├ Bin_Wfm_Type
#     ├ Excitation_Waveform
#     ├ Noise_Floor
#     ├ Position_Indices
#     ├ Position_Values
#     ├ Raw_Data
#     ├ Spatially_Averaged_Plot_Group_000
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spatially_Averaged_Plot_Group_001
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ UDVS
#     ├ UDVS_Indices
# Datasets and datagroups within the file:
# ------------------------------------
# /
# /Measurement_000
# /Measurement_000/Channel_000
# /Measurement_000/Channel_000/Bin_FFT
# /Measurement_000/Channel_000/Bin_Frequencies
# /Measurement_000/Channel_000/Bin_Indices
# /Measurement_000/Channel_000/Bin_Step
# /Measurement_000/Channel_000/Bin_Wfm_Type
# /Measurement_000/Channel_000/Excitation_Waveform
# /Measurement_000/Channel_000/Noise_Floor
# /Measurement_000/Channel_000/Position_Indices
# /Measurement_000/Channel_000/Position_Values
# /Measurement_000/Channel_000/Raw_Data
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Step_Averaged_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Step_Averaged_Response
# /Measurement_000/Channel_000/Spectroscopic_Indices
# /Measurement_000/Channel_000/Spectroscopic_Values
# /Measurement_000/Channel_000/UDVS
# /Measurement_000/Channel_000/UDVS_Indices
#
# The main dataset:
# ------------------------------------
# <HDF5 file "data_raw7.h5" (mode r+)>
#
# The ancillary datasets:
# ------------------------------------
# <HDF5 dataset "Position_Indices": shape (3600, 2), type "<u4">
# <HDF5 dataset "Position_Values": shape (3600, 2), type "<f4">
# <HDF5 dataset "Spectroscopic_Indices": shape (4, 63360), type "<u4">
# <HDF5 dataset "Spectroscopic_Values": shape (4, 63360), type "<f4">
#
# Metadata or attributes in a datagroup
# ------------------------------------
# BE_actual_duration_[s] : 0.004
# BE_amplitude_[V] : 1
# BE_auto_smoothing : auto smoothing on
# BE_band_edge_smoothing_[s] : 4832.1
# BE_band_edge_trim : 0.094742
# BE_band_width_[Hz] : 200000
# BE_bins_per_band : 0
# BE_center_frequency_[Hz] : 1310000
# BE_desired_duration_[s] : 0.004
# BE_phase_content : chirp-sinc hybrid
# BE_phase_variation : 1
# BE_points_per_BE_wave : 0
# BE_repeats : 4
# FORC_V_high1_[V] : 1
# FORC_V_high2_[V] : 10
# FORC_V_low1_[V] : -1
# FORC_V_low2_[V] : -10
# FORC_num_of_FORC_cycles : 1
# FORC_num_of_FORC_repeats : 1
# File_MDAQ_version : MDAQ_VS_090915_01
# File_date_and_time : 18-Sep-2015 18:32:14
# File_file_name : SP128_NSO
# File_file_path : C:\Users\Asylum User\Documents\Users\Agar\SP128_NSO\
# File_file_suffix : 99
# IO_AO_amplifier : 10
# IO_AO_range_[V] : +/- 10
# IO_Analog_Input_1 : +/- .1V, FFT
# IO_Analog_Input_2 : off
# IO_Analog_Input_3 : off
# IO_Analog_Input_4 : off
# IO_DAQ_platform : NI 6115
# IO_rate_[Hz] : 4000000
# VS_amplitude_[V] : 16
# VS_cycle_fraction : full
# VS_cycle_phase_shift : 0
# VS_measure_in_field_loops : in and out-of-field
# VS_mode : DC modulation mode
# VS_number_of_cycles : 2
# VS_offset_[V] : 0
# VS_read_voltage_[V] : 0
# VS_set_pulse_amplitude[V] : 0
# VS_set_pulse_duration[s] : 0.002
# VS_step_edge_smoothing_[s] : 0.001
# VS_steps_per_full_cycle : 96
# data_type : BEPSData
# grid_/single : grid
# grid_contact_set_point_[V] : 1
# grid_current_col : 1
# grid_current_row : 1
# grid_cycle_time_[s] : 10
# grid_measuring : 0
# grid_moving : 0
# grid_num_cols : 60
# grid_num_rows : 60
# grid_settle_time_[s] : 0.15
# grid_time_remaining_[h;m;s] : 10
# grid_total_time_[h;m;s] : 10
# grid_transit_set_point_[V] : 0.1
# grid_transit_time_[s] : 0.15
# num_bins : 165
# num_pix : 3600
# num_udvs_steps : 384

# %% [markdown]
# ## Generates Noisy Data
#
# This function will generate noisy records and save them as an h5_main file in the USID format. This allows the data to be computed with the Pycroscopy SHO Fitter.

# %%
# calculates the standard deviation and uses that for the noise
noise_STD = np.std(dataset.raw_SHO_data)

# prints the standard deviation
print(noise_STD)
# Out:
# 0.0038833667

# %%
dataset.raw_SHO_data.shape
# Out:
# (3600, 63360)

# %%
dataset.print_be_tree
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ Bin_FFT
#     ├ Bin_Frequencies
#     ├ Bin_Indices
#     ├ Bin_Step
#     ├ Bin_Wfm_Type
#     ├ Excitation_Waveform
#     ├ Noise_Floor
#     ├ Position_Indices
#     ├ Position_Values
#     ├ Raw_Data
#     ├ Spatially_Averaged_Plot_Group_000
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spatially_Averaged_Plot_Group_001
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ UDVS
#     ├ UDVS_Indices
# Datasets and datagroups within the file:
# ------------------------------------
# /
# /Measurement_000
# /Measurement_000/Channel_000
# /Measurement_000/Channel_000/Bin_FFT
# /Measurement_000/Channel_000/Bin_Frequencies
# /Measurement_000/Channel_000/Bin_Indices
# /Measurement_000/Channel_000/Bin_Step
# /Measurement_000/Channel_000/Bin_Wfm_Type
# /Measurement_000/Channel_000/Excitation_Waveform
# /Measurement_000/Channel_000/Noise_Floor
# /Measurement_000/Channel_000/Position_Indices
# /Measurement_000/Channel_000/Position_Values
# /Measurement_000/Channel_000/Raw_Data
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Step_Averaged_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Step_Averaged_Response
# /Measurement_000/Channel_000/Spectroscopic_Indices
# /Measurement_000/Channel_000/Spectroscopic_Values
# /Measurement_000/Channel_000/UDVS
# /Measurement_000/Channel_000/UDVS_Indices
#
# The main dataset:
# ------------------------------------
# <HDF5 file "data_raw7.h5" (mode r+)>
#
# The ancillary datasets:
# ------------------------------------
# <HDF5 dataset "Position_Indices": shape (3600, 2), type "<u4">
# <HDF5 dataset "Position_Values": shape (3600, 2), type "<f4">
# <HDF5 dataset "Spectroscopic_Indices": shape (4, 63360), type "<u4">
# <HDF5 dataset "Spectroscopic_Values": shape (4, 63360), type "<f4">
#
# Metadata or attributes in a datagroup
# ------------------------------------
# BE_actual_duration_[s] : 0.004
# BE_amplitude_[V] : 1
# BE_auto_smoothing : auto smoothing on
# BE_band_edge_smoothing_[s] : 4832.1
# BE_band_edge_trim : 0.094742
# BE_band_width_[Hz] : 200000
# BE_bins_per_band : 0
# BE_center_frequency_[Hz] : 1310000
# BE_desired_duration_[s] : 0.004
# BE_phase_content : chirp-sinc hybrid
# BE_phase_variation : 1
# BE_points_per_BE_wave : 0
# BE_repeats : 4
# FORC_V_high1_[V] : 1
# FORC_V_high2_[V] : 10
# FORC_V_low1_[V] : -1
# FORC_V_low2_[V] : -10
# FORC_num_of_FORC_cycles : 1
# FORC_num_of_FORC_repeats : 1
# File_MDAQ_version : MDAQ_VS_090915_01
# File_date_and_time : 18-Sep-2015 18:32:14
# File_file_name : SP128_NSO
# File_file_path : C:\Users\Asylum User\Documents\Users\Agar\SP128_NSO\
# File_file_suffix : 99
# IO_AO_amplifier : 10
# IO_AO_range_[V] : +/- 10
# IO_Analog_Input_1 : +/- .1V, FFT
# IO_Analog_Input_2 : off
# IO_Analog_Input_3 : off
# IO_Analog_Input_4 : off
# IO_DAQ_platform : NI 6115
# IO_rate_[Hz] : 4000000
# VS_amplitude_[V] : 16
# VS_cycle_fraction : full
# VS_cycle_phase_shift : 0
# VS_measure_in_field_loops : in and out-of-field
# VS_mode : DC modulation mode
# VS_number_of_cycles : 2
# VS_offset_[V] : 0
# VS_read_voltage_[V] : 0
# VS_set_pulse_amplitude[V] : 0
# VS_set_pulse_duration[s] : 0.002
# VS_step_edge_smoothing_[s] : 0.001
# VS_steps_per_full_cycle : 96
# data_type : BEPSData
# grid_/single : grid
# grid_contact_set_point_[V] : 1
# grid_current_col : 1
# grid_current_row : 1
# grid_cycle_time_[s] : 10
# grid_measuring : 0
# grid_moving : 0
# grid_num_cols : 60
# grid_num_rows : 60
# grid_settle_time_[s] : 0.15
# grid_time_remaining_[h;m;s] : 10
# grid_total_time_[h;m;s] : 10
# grid_transit_set_point_[V] : 0.1
# grid_transit_time_[s] : 0.15
# num_bins : 165
# num_pix : 3600
# num_udvs_steps : 384

# %%
from m3util.util.h5 import find_groups_with_string
find_groups_with_string(dataset.file, "Noisy_Data_1")
# Out:
# []

# %%
import pyUSID as usid
import h5py
with h5py.File(dataset.file, "r+") as h5_file:

    h5_main = usid.hdf_utils.find_dataset(h5_file, "Noisy_Data_1")[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 5
#       2 import h5py
#       3 with h5py.File(dataset.file, "r+") as h5_file:
# ----> 5     h5_main = usid.hdf_utils.find_dataset(h5_file, "Noisy_Data_1")[0]
#
# IndexError: list index out of range

# %%
dataset.generate_noisy_data_records(noise_levels = np.arange(1,9), 
                                    verbose=True, 
                                    noise_STD=noise_STD)
# Out:
# Noise standard deviation: 0.0038833667058497667
# The STD of the data is: 0.0038833667058497667
# Adding noise level 1
# Adding noise level 2
# Adding noise level 3
# Adding noise level 4
# Adding noise level 5
# Adding noise level 6
# Adding noise level 7
# Adding noise level 8

# %%
dataset.print_be_tree
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ Bin_FFT
#     ├ Bin_Frequencies
#     ├ Bin_Indices
#     ├ Bin_Step
#     ├ Bin_Wfm_Type
#     ├ Excitation_Waveform
#     ├ Noise_Floor
#     ├ Noisy_Data_1
#     ├ Noisy_Data_2
#     ├ Noisy_Data_3
#     ├ Noisy_Data_4
#     ├ Noisy_Data_5
#     ├ Noisy_Data_6
#     ├ Noisy_Data_7
#     ├ Noisy_Data_8
#     ├ Position_Indices
#     ├ Position_Values
#     ├ Raw_Data
#     ├ Spatially_Averaged_Plot_Group_000
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spatially_Averaged_Plot_Group_001
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ UDVS
#     ├ UDVS_Indices
# Datasets and datagroups within the file:
# ------------------------------------
# /
# /Measurement_000
# /Measurement_000/Channel_000
# /Measurement_000/Channel_000/Bin_FFT
# /Measurement_000/Channel_000/Bin_Frequencies
# /Measurement_000/Channel_000/Bin_Indices
# /Measurement_000/Channel_000/Bin_Step
# /Measurement_000/Channel_000/Bin_Wfm_Type
# /Measurement_000/Channel_000/Excitation_Waveform
# /Measurement_000/Channel_000/Noise_Floor
# /Measurement_000/Channel_000/Noisy_Data_1
# /Measurement_000/Channel_000/Noisy_Data_2
# /Measurement_000/Channel_000/Noisy_Data_3
# /Measurement_000/Channel_000/Noisy_Data_4
# /Measurement_000/Channel_000/Noisy_Data_5
# /Measurement_000/Channel_000/Noisy_Data_6
# /Measurement_000/Channel_000/Noisy_Data_7
# /Measurement_000/Channel_000/Noisy_Data_8
# /Measurement_000/Channel_000/Position_Indices
# /Measurement_000/Channel_000/Position_Values
# /Measurement_000/Channel_000/Raw_Data
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Step_Averaged_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Step_Averaged_Response
# /Measurement_000/Channel_000/Spectroscopic_Indices
# /Measurement_000/Channel_000/Spectroscopic_Values
# /Measurement_000/Channel_000/UDVS
# /Measurement_000/Channel_000/UDVS_Indices
#
# The main dataset:
# ------------------------------------
# <HDF5 file "data_raw7.h5" (mode r+)>
#
# The ancillary datasets:
# ------------------------------------
# <HDF5 dataset "Position_Indices": shape (3600, 2), type "<u4">
# <HDF5 dataset "Position_Values": shape (3600, 2), type "<f4">
# <HDF5 dataset "Spectroscopic_Indices": shape (4, 63360), type "<u4">
# <HDF5 dataset "Spectroscopic_Values": shape (4, 63360), type "<f4">
#
# Metadata or attributes in a datagroup
# ------------------------------------
# BE_actual_duration_[s] : 0.004
# BE_amplitude_[V] : 1
# BE_auto_smoothing : auto smoothing on
# BE_band_edge_smoothing_[s] : 4832.1
# BE_band_edge_trim : 0.094742
# BE_band_width_[Hz] : 200000
# BE_bins_per_band : 0
# BE_center_frequency_[Hz] : 1310000
# BE_desired_duration_[s] : 0.004
# BE_phase_content : chirp-sinc hybrid
# BE_phase_variation : 1
# BE_points_per_BE_wave : 0
# BE_repeats : 4
# FORC_V_high1_[V] : 1
# FORC_V_high2_[V] : 10
# FORC_V_low1_[V] : -1
# FORC_V_low2_[V] : -10
# FORC_num_of_FORC_cycles : 1
# FORC_num_of_FORC_repeats : 1
# File_MDAQ_version : MDAQ_VS_090915_01
# File_date_and_time : 18-Sep-2015 18:32:14
# File_file_name : SP128_NSO
# File_file_path : C:\Users\Asylum User\Documents\Users\Agar\SP128_NSO\
# File_file_suffix : 99
# IO_AO_amplifier : 10
# IO_AO_range_[V] : +/- 10
# IO_Analog_Input_1 : +/- .1V, FFT
# IO_Analog_Input_2 : off
# IO_Analog_Input_3 : off
# IO_Analog_Input_4 : off
# IO_DAQ_platform : NI 6115
# IO_rate_[Hz] : 4000000
# VS_amplitude_[V] : 16
# VS_cycle_fraction : full
# VS_cycle_phase_shift : 0
# VS_measure_in_field_loops : in and out-of-field
# VS_mode : DC modulation mode
# VS_number_of_cycles : 2
# VS_offset_[V] : 0
# VS_read_voltage_[V] : 0
# VS_set_pulse_amplitude[V] : 0
# VS_set_pulse_duration[s] : 0.002
# VS_step_edge_smoothing_[s] : 0.001
# VS_steps_per_full_cycle : 96
# data_type : BEPSData
# grid_/single : grid
# grid_contact_set_point_[V] : 1
# grid_current_col : 1
# grid_current_row : 1
# grid_cycle_time_[s] : 10
# grid_measuring : 0
# grid_moving : 0
# grid_num_cols : 60
# grid_num_rows : 60
# grid_settle_time_[s] : 0.15
# grid_time_remaining_[h;m;s] : 10
# grid_total_time_[h;m;s] : 10
# grid_transit_set_point_[V] : 0.1
# grid_transit_time_[s] : 0.15
# num_bins : 165
# num_pix : 3600
# num_udvs_steps : 384

# %%
from m3util.util.h5 import find_measurement
find_measurement(dataset.file, "Noisy_Data_1",group = "Measurement_000/Channel_000")
# Out:
# 'Noisy_Data_1'

# %%
find_groups_with_string(dataset.file, "Noisy_Data_1")
# Out:
# []

# %%
with h5py.File(dataset.file, "r+") as h5_file:

    print(usid.hdf_utils.find_dataset(h5_file, "Noisy_Data_1")[0])
# Out:
# <HDF5 dataset "Noisy_Data_1": shape (3600, 63360), type "<c16">
# located at:
# 	/Measurement_000/Channel_000/Noisy_Data_1
# Data contains:
# 	Piezoresponse (V)
# Data dimensions and original shape:
# Position Dimensions:
# 	Y - size: 60
# 	X - size: 60
# Spectroscopic Dimensions:
# 	Frequency - size: 165
# 	DC_Offset - size: 96
# 	Field - size: 2
# 	Cycle - size: 2
# Data Type:
# 	complex128

# %%
find_groups_with_string(dataset.file, "Noisy_Data_2") != []
# Out:
# False

# %% [markdown]
# ## SHO fits on all the datasets
#
# This will take some time, Each fit takes about 10 minutes to complete.

# %%
out = [f"Noisy_Data_{i}" for i in np.arange(1,9)]
out.append("Raw_Data")

for data in out:
    print(f"Fitting {data}")
    dataset.SHO_Fitter(dataset = data, h5_sho_targ_grp = f"{data}_SHO_Fit", max_mem=1024*64, max_cores= 20)
# Out:
# Fitting Noisy_Data_1
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.47 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.12 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.94 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.82 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.71 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.54 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.46 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.38 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.3 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.22 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.14 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.07 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 59.15 sec
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 54.64 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 50.06 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 45.46 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 40.73 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 36.16 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 31.41 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 26.74 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 21.99 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 17.24 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 12.62 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.03 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.34 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 4.68 mins
# Rank 0 - 6% complete. Time remaining: 3.5 mins
# Rank 0 - 10% complete. Time remaining: 3.04 mins
# Rank 0 - 13% complete. Time remaining: 2.86 mins
# Rank 0 - 16% complete. Time remaining: 2.64 mins
# Rank 0 - 20% complete. Time remaining: 2.18 mins
# Rank 0 - 23% complete. Time remaining: 2.07 mins
# Rank 0 - 26% complete. Time remaining: 1.96 mins
# Rank 0 - 30% complete. Time remaining: 1.81 mins
# Rank 0 - 33% complete. Time remaining: 1.74 mins
# Rank 0 - 36% complete. Time remaining: 1.63 mins
# Rank 0 - 40% complete. Time remaining: 1.56 mins
# Rank 0 - 43% complete. Time remaining: 1.5 mins
# Rank 0 - 46% complete. Time remaining: 1.42 mins
# Rank 0 - 50% complete. Time remaining: 1.28 mins
# Rank 0 - 53% complete. Time remaining: 1.2 mins
# Rank 0 - 56% complete. Time remaining: 1.12 mins
# Rank 0 - 60% complete. Time remaining: 1.02 mins
# Rank 0 - 63% complete. Time remaining: 55.97 sec
# Rank 0 - 66% complete. Time remaining: 52.96 sec
# Rank 0 - 70% complete. Time remaining: 47.88 sec
# Rank 0 - 73% complete. Time remaining: 42.51 sec
# Rank 0 - 76% complete. Time remaining: 36.74 sec
# Rank 0 - 80% complete. Time remaining: 31.3 sec
# Rank 0 - 83% complete. Time remaining: 25.1 sec
# Rank 0 - 86% complete. Time remaining: 19.91 sec
# Rank 0 - 90% complete. Time remaining: 14.74 sec
# Rank 0 - 93% complete. Time remaining: 9.77 sec
# Rank 0 - 96% complete. Time remaining: 5.09 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 333.86662101745605 seconds to compute parameters
# Fitting Noisy_Data_2
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.08 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 1.94 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.83 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.73 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.65 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.55 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.49 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.41 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.34 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.26 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.18 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.08 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 59.99 sec
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 55.34 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 50.55 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 45.91 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 41.32 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 36.57 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 31.87 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 27.27 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 22.65 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 17.79 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 13.01 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.18 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.38 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.56 mins
# Rank 0 - 6% complete. Time remaining: 2.48 mins
# Rank 0 - 10% complete. Time remaining: 2.37 mins
# Rank 0 - 13% complete. Time remaining: 2.36 mins
# Rank 0 - 16% complete. Time remaining: 2.25 mins
# Rank 0 - 20% complete. Time remaining: 2.15 mins
# Rank 0 - 23% complete. Time remaining: 2.08 mins
# Rank 0 - 26% complete. Time remaining: 2.0 mins
# Rank 0 - 30% complete. Time remaining: 1.9 mins
# Rank 0 - 33% complete. Time remaining: 1.88 mins
# Rank 0 - 36% complete. Time remaining: 1.79 mins
# Rank 0 - 40% complete. Time remaining: 1.68 mins
# Rank 0 - 43% complete. Time remaining: 1.59 mins
# Rank 0 - 46% complete. Time remaining: 1.46 mins
# Rank 0 - 50% complete. Time remaining: 1.32 mins
# Rank 0 - 53% complete. Time remaining: 1.22 mins
# Rank 0 - 56% complete. Time remaining: 1.13 mins
# Rank 0 - 60% complete. Time remaining: 1.03 mins
# Rank 0 - 63% complete. Time remaining: 59.18 sec
# Rank 0 - 66% complete. Time remaining: 53.98 sec
# Rank 0 - 70% complete. Time remaining: 48.58 sec
# Rank 0 - 73% complete. Time remaining: 42.45 sec
# Rank 0 - 76% complete. Time remaining: 37.02 sec
# Rank 0 - 80% complete. Time remaining: 30.26 sec
# Rank 0 - 83% complete. Time remaining: 25.18 sec
# Rank 0 - 86% complete. Time remaining: 20.26 sec
# Rank 0 - 90% complete. Time remaining: 15.53 sec
# Rank 0 - 93% complete. Time remaining: 10.69 sec
# Rank 0 - 96% complete. Time remaining: 5.39 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 329.46953654289246 seconds to compute parameters
# Fitting Noisy_Data_3
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.28 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.02 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.89 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.77 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.68 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.54 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.47 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.39 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.32 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.25 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.17 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.09 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.01 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 56.11 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 51.36 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 46.57 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 41.79 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 37.15 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 32.0 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 27.05 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 22.29 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 17.55 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 12.8 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.08 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.38 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.56 mins
# Rank 0 - 6% complete. Time remaining: 2.45 mins
# Rank 0 - 10% complete. Time remaining: 2.32 mins
# Rank 0 - 13% complete. Time remaining: 2.34 mins
# Rank 0 - 16% complete. Time remaining: 2.25 mins
# Rank 0 - 20% complete. Time remaining: 2.15 mins
# Rank 0 - 23% complete. Time remaining: 2.05 mins
# Rank 0 - 26% complete. Time remaining: 1.94 mins
# Rank 0 - 30% complete. Time remaining: 1.8 mins
# Rank 0 - 33% complete. Time remaining: 1.76 mins
# Rank 0 - 36% complete. Time remaining: 1.68 mins
# Rank 0 - 40% complete. Time remaining: 1.6 mins
# Rank 0 - 43% complete. Time remaining: 1.54 mins
# Rank 0 - 46% complete. Time remaining: 1.45 mins
# Rank 0 - 50% complete. Time remaining: 1.31 mins
# Rank 0 - 53% complete. Time remaining: 1.2 mins
# Rank 0 - 56% complete. Time remaining: 1.12 mins
# Rank 0 - 60% complete. Time remaining: 1.03 mins
# Rank 0 - 63% complete. Time remaining: 56.12 sec
# Rank 0 - 66% complete. Time remaining: 52.96 sec
# Rank 0 - 70% complete. Time remaining: 48.33 sec
# Rank 0 - 73% complete. Time remaining: 42.83 sec
# Rank 0 - 76% complete. Time remaining: 37.52 sec
# Rank 0 - 80% complete. Time remaining: 32.2 sec
# Rank 0 - 83% complete. Time remaining: 26.04 sec
# Rank 0 - 86% complete. Time remaining: 21.46 sec
# Rank 0 - 90% complete. Time remaining: 15.98 sec
# Rank 0 - 93% complete. Time remaining: 10.6 sec
# Rank 0 - 96% complete. Time remaining: 5.28 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 327.8204252719879 seconds to compute parameters
# Fitting Noisy_Data_4
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.52 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.18 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 2.0 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.9 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.77 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.6 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.51 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.43 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.34 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.26 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.18 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.1 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.02 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 56.39 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 51.49 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 46.65 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 41.81 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 36.94 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 32.05 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 27.27 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 22.49 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 17.78 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 13.01 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.2 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.42 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.56 mins
# Rank 0 - 6% complete. Time remaining: 2.39 mins
# Rank 0 - 10% complete. Time remaining: 2.3 mins
# Rank 0 - 13% complete. Time remaining: 2.27 mins
# Rank 0 - 16% complete. Time remaining: 2.17 mins
# Rank 0 - 20% complete. Time remaining: 2.08 mins
# Rank 0 - 23% complete. Time remaining: 2.03 mins
# Rank 0 - 26% complete. Time remaining: 1.95 mins
# Rank 0 - 30% complete. Time remaining: 1.82 mins
# Rank 0 - 33% complete. Time remaining: 1.81 mins
# Rank 0 - 36% complete. Time remaining: 1.72 mins
# Rank 0 - 40% complete. Time remaining: 1.61 mins
# Rank 0 - 43% complete. Time remaining: 1.52 mins
# Rank 0 - 46% complete. Time remaining: 1.45 mins
# Rank 0 - 50% complete. Time remaining: 1.32 mins
# Rank 0 - 53% complete. Time remaining: 1.23 mins
# Rank 0 - 56% complete. Time remaining: 1.15 mins
# Rank 0 - 60% complete. Time remaining: 1.06 mins
# Rank 0 - 63% complete. Time remaining: 57.99 sec
# Rank 0 - 66% complete. Time remaining: 52.82 sec
# Rank 0 - 70% complete. Time remaining: 47.65 sec
# Rank 0 - 73% complete. Time remaining: 43.23 sec
# Rank 0 - 76% complete. Time remaining: 37.49 sec
# Rank 0 - 80% complete. Time remaining: 32.12 sec
# Rank 0 - 83% complete. Time remaining: 26.95 sec
# Rank 0 - 86% complete. Time remaining: 21.55 sec
# Rank 0 - 90% complete. Time remaining: 15.74 sec
# Rank 0 - 93% complete. Time remaining: 10.56 sec
# Rank 0 - 96% complete. Time remaining: 5.24 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 328.8551392555237 seconds to compute parameters
# Fitting Noisy_Data_5
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.46 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.14 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.96 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.84 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.74 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.58 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.49 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.42 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.34 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.25 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.17 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.09 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.02 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 56.18 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 51.32 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 46.57 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 41.67 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 36.74 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 32.0 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 27.38 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 22.64 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 17.89 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 13.06 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.23 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.42 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.56 mins
# Rank 0 - 6% complete. Time remaining: 2.49 mins
# Rank 0 - 10% complete. Time remaining: 2.32 mins
# Rank 0 - 13% complete. Time remaining: 2.34 mins
# Rank 0 - 16% complete. Time remaining: 2.24 mins
# Rank 0 - 20% complete. Time remaining: 2.17 mins
# Rank 0 - 23% complete. Time remaining: 2.04 mins
# Rank 0 - 26% complete. Time remaining: 1.98 mins
# Rank 0 - 30% complete. Time remaining: 1.87 mins
# Rank 0 - 33% complete. Time remaining: 1.82 mins
# Rank 0 - 36% complete. Time remaining: 1.72 mins
# Rank 0 - 40% complete. Time remaining: 1.65 mins
# Rank 0 - 43% complete. Time remaining: 1.54 mins
# Rank 0 - 46% complete. Time remaining: 1.41 mins
# Rank 0 - 50% complete. Time remaining: 1.28 mins
# Rank 0 - 53% complete. Time remaining: 1.19 mins
# Rank 0 - 56% complete. Time remaining: 1.1 mins
# Rank 0 - 60% complete. Time remaining: 1.04 mins
# Rank 0 - 63% complete. Time remaining: 59.95 sec
# Rank 0 - 66% complete. Time remaining: 54.52 sec
# Rank 0 - 70% complete. Time remaining: 49.16 sec
# Rank 0 - 73% complete. Time remaining: 43.76 sec
# Rank 0 - 76% complete. Time remaining: 37.72 sec
# Rank 0 - 80% complete. Time remaining: 31.08 sec
# Rank 0 - 83% complete. Time remaining: 26.08 sec
# Rank 0 - 86% complete. Time remaining: 20.65 sec
# Rank 0 - 90% complete. Time remaining: 15.94 sec
# Rank 0 - 93% complete. Time remaining: 10.57 sec
# Rank 0 - 96% complete. Time remaining: 5.28 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 328.15640592575073 seconds to compute parameters
# Fitting Noisy_Data_6
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.14 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 1.98 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.88 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.78 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.68 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.57 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.49 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.41 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.33 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.25 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.17 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.1 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.02 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 56.28 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 51.45 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 46.86 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 41.69 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 36.78 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 32.13 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 27.31 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 22.44 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 17.69 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 12.92 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.12 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.38 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.5 mins
# Rank 0 - 6% complete. Time remaining: 2.4 mins
# Rank 0 - 10% complete. Time remaining: 2.46 mins
# Rank 0 - 13% complete. Time remaining: 2.32 mins
# Rank 0 - 16% complete. Time remaining: 2.21 mins
# Rank 0 - 20% complete. Time remaining: 2.14 mins
# Rank 0 - 23% complete. Time remaining: 2.06 mins
# Rank 0 - 26% complete. Time remaining: 1.9 mins
# Rank 0 - 30% complete. Time remaining: 1.84 mins
# Rank 0 - 33% complete. Time remaining: 1.77 mins
# Rank 0 - 36% complete. Time remaining: 1.66 mins
# Rank 0 - 40% complete. Time remaining: 1.56 mins
# Rank 0 - 43% complete. Time remaining: 1.49 mins
# Rank 0 - 46% complete. Time remaining: 1.38 mins
# Rank 0 - 50% complete. Time remaining: 1.29 mins
# Rank 0 - 53% complete. Time remaining: 1.21 mins
# Rank 0 - 56% complete. Time remaining: 1.14 mins
# Rank 0 - 60% complete. Time remaining: 1.05 mins
# Rank 0 - 63% complete. Time remaining: 58.12 sec
# Rank 0 - 66% complete. Time remaining: 52.68 sec
# Rank 0 - 70% complete. Time remaining: 47.39 sec
# Rank 0 - 73% complete. Time remaining: 41.52 sec
# Rank 0 - 76% complete. Time remaining: 37.77 sec
# Rank 0 - 80% complete. Time remaining: 32.15 sec
# Rank 0 - 83% complete. Time remaining: 26.85 sec
# Rank 0 - 86% complete. Time remaining: 21.5 sec
# Rank 0 - 90% complete. Time remaining: 16.13 sec
# Rank 0 - 93% complete. Time remaining: 10.2 sec
# Rank 0 - 96% complete. Time remaining: 5.06 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 325.3976593017578 seconds to compute parameters
# Fitting Noisy_Data_7
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.21 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.01 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.88 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.78 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.68 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.57 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.49 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.41 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.33 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.25 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.17 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.09 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.01 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 55.81 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 51.0 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 46.22 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 41.43 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 36.66 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 31.87 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 27.22 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 22.46 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 17.67 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 12.89 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.16 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.4 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.56 mins
# Rank 0 - 6% complete. Time remaining: 2.42 mins
# Rank 0 - 10% complete. Time remaining: 2.31 mins
# Rank 0 - 13% complete. Time remaining: 2.34 mins
# Rank 0 - 16% complete. Time remaining: 2.24 mins
# Rank 0 - 20% complete. Time remaining: 2.15 mins
# Rank 0 - 23% complete. Time remaining: 2.05 mins
# Rank 0 - 26% complete. Time remaining: 1.97 mins
# Rank 0 - 30% complete. Time remaining: 1.81 mins
# Rank 0 - 33% complete. Time remaining: 1.77 mins
# Rank 0 - 36% complete. Time remaining: 1.68 mins
# Rank 0 - 40% complete. Time remaining: 1.59 mins
# Rank 0 - 43% complete. Time remaining: 1.5 mins
# Rank 0 - 46% complete. Time remaining: 1.4 mins
# Rank 0 - 50% complete. Time remaining: 1.26 mins
# Rank 0 - 53% complete. Time remaining: 1.17 mins
# Rank 0 - 56% complete. Time remaining: 1.07 mins
# Rank 0 - 60% complete. Time remaining: 59.74 sec
# Rank 0 - 63% complete. Time remaining: 55.57 sec
# Rank 0 - 66% complete. Time remaining: 51.06 sec
# Rank 0 - 70% complete. Time remaining: 47.93 sec
# Rank 0 - 73% complete. Time remaining: 43.3 sec
# Rank 0 - 76% complete. Time remaining: 38.01 sec
# Rank 0 - 80% complete. Time remaining: 31.98 sec
# Rank 0 - 83% complete. Time remaining: 26.56 sec
# Rank 0 - 86% complete. Time remaining: 20.34 sec
# Rank 0 - 90% complete. Time remaining: 15.29 sec
# Rank 0 - 93% complete. Time remaining: 10.18 sec
# Rank 0 - 96% complete. Time remaining: 5.21 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 325.07307028770447 seconds to compute parameters
# Fitting Noisy_Data_8
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.15 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 1.96 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.85 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.75 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.67 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.55 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.48 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.4 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.33 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.25 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.17 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.08 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.0 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 55.17 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 50.59 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 46.08 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 41.48 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 36.69 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 32.0 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 27.14 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 22.36 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 17.63 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 12.88 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.31 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.47 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.53 mins
# Rank 0 - 6% complete. Time remaining: 2.43 mins
# Rank 0 - 10% complete. Time remaining: 2.29 mins
# Rank 0 - 13% complete. Time remaining: 2.3 mins
# Rank 0 - 16% complete. Time remaining: 2.2 mins
# Rank 0 - 20% complete. Time remaining: 2.12 mins
# Rank 0 - 23% complete. Time remaining: 2.03 mins
# Rank 0 - 26% complete. Time remaining: 1.97 mins
# Rank 0 - 30% complete. Time remaining: 1.82 mins
# Rank 0 - 33% complete. Time remaining: 1.77 mins
# Rank 0 - 36% complete. Time remaining: 1.66 mins
# Rank 0 - 40% complete. Time remaining: 1.56 mins
# Rank 0 - 43% complete. Time remaining: 1.46 mins
# Rank 0 - 46% complete. Time remaining: 1.38 mins
# Rank 0 - 50% complete. Time remaining: 1.27 mins
# Rank 0 - 53% complete. Time remaining: 1.21 mins
# Rank 0 - 56% complete. Time remaining: 1.14 mins
# Rank 0 - 60% complete. Time remaining: 1.05 mins
# Rank 0 - 63% complete. Time remaining: 57.71 sec
# Rank 0 - 66% complete. Time remaining: 54.22 sec
# Rank 0 - 70% complete. Time remaining: 48.74 sec
# Rank 0 - 73% complete. Time remaining: 43.06 sec
# Rank 0 - 76% complete. Time remaining: 37.76 sec
# Rank 0 - 80% complete. Time remaining: 32.44 sec
# Rank 0 - 83% complete. Time remaining: 26.05 sec
# Rank 0 - 86% complete. Time remaining: 20.81 sec
# Rank 0 - 90% complete. Time remaining: 15.55 sec
# Rank 0 - 93% complete. Time remaining: 10.82 sec
# Rank 0 - 96% complete. Time remaining: 5.43 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 326.8861038684845 seconds to compute parameters
# Fitting Raw_Data
# Working on:
# ./Data//data_raw6.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw6.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 1.96 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.8 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.64 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.47 mins
# Rank 0 finished parallel computation
# Rank 0 - 39% complete. Time remaining: 1.31 mins
# Rank 0 finished parallel computation
# Rank 0 - 47% complete. Time remaining: 1.14 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 58.65 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 48.57 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 38.41 sec
# Rank 0 finished parallel computation
# Rank 0 - 78% complete. Time remaining: 28.21 sec
# Rank 0 finished parallel computation
# Rank 0 - 86% complete. Time remaining: 18.02 sec
# Rank 0 finished parallel computation
# Rank 0 - 94% complete. Time remaining: 7.8 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/julian/anaconda3/envs/BEPFM/lib/python3.10/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 6% complete. Time remaining: 1.99 mins
# Rank 0 - 13% complete. Time remaining: 2.2 mins
# Rank 0 - 20% complete. Time remaining: 1.89 mins
# Rank 0 - 26% complete. Time remaining: 1.83 mins
# Rank 0 - 33% complete. Time remaining: 1.73 mins
# Rank 0 - 40% complete. Time remaining: 1.56 mins
# Rank 0 - 46% complete. Time remaining: 1.4 mins
# Rank 0 - 53% complete. Time remaining: 1.22 mins
# Rank 0 - 60% complete. Time remaining: 1.04 mins
# Rank 0 - 66% complete. Time remaining: 48.39 sec
# Rank 0 - 73% complete. Time remaining: 41.05 sec
# Rank 0 - 80% complete. Time remaining: 30.2 sec
# Rank 0 - 87% complete. Time remaining: 20.2 sec
# Rank 0 - 93% complete. Time remaining: 9.85 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 342.3257441520691 seconds to compute parameters

# %% [markdown]
# ### Checks the results to make sure it was saved correctly

# %%
# print the contents of the file
dataset.print_be_tree
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ Bin_FFT
#     ├ Bin_Frequencies
#     ├ Bin_Indices
#     ├ Bin_Step
#     ├ Bin_Wfm_Type
#     ├ Excitation_Waveform
#     ├ Noise_Floor
#     ├ Noisy_Data_1
#     ├ Noisy_Data_2
#     ├ Noisy_Data_3
#     ├ Noisy_Data_4
#     ├ Noisy_Data_5
#     ├ Noisy_Data_6
#     ├ Noisy_Data_7
#     ├ Noisy_Data_8
#     ├ Position_Indices
#     ├ Position_Values
#     ├ Raw_Data
#     ├ Spatially_Averaged_Plot_Group_000
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spatially_Averaged_Plot_Group_001
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ UDVS
#     ├ UDVS_Indices
# ├ Noisy_Data_1_SHO_Fit
#   --------------------
#   ├ Noisy_Data_1-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_2_SHO_Fit
#   --------------------
#   ├ Noisy_Data_2-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_3_SHO_Fit
#   --------------------
#   ├ Noisy_Data_3-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_4_SHO_Fit
#   --------------------
#   ├ Noisy_Data_4-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_5_SHO_Fit
#   --------------------
#   ├ Noisy_Data_5-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_6_SHO_Fit
#   --------------------
#   ├ Noisy_Data_6-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_7_SHO_Fit
#   --------------------
#   ├ Noisy_Data_7-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_8_SHO_Fit
#   --------------------
#   ├ Noisy_Data_8-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Raw_Data_SHO_Fit
#   ----------------
#   ├ Raw_Data-SHO_Fit_000
#     --------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# Datasets and datagroups within the file:
# ------------------------------------
# /
# /Measurement_000
# /Measurement_000/Channel_000
# /Measurement_000/Channel_000/Bin_FFT
# /Measurement_000/Channel_000/Bin_Frequencies
# /Measurement_000/Channel_000/Bin_Indices
# /Measurement_000/Channel_000/Bin_Step
# /Measurement_000/Channel_000/Bin_Wfm_Type
# /Measurement_000/Channel_000/Excitation_Waveform
# /Measurement_000/Channel_000/Noise_Floor
# /Measurement_000/Channel_000/Noisy_Data_1
# /Measurement_000/Channel_000/Noisy_Data_2
# /Measurement_000/Channel_000/Noisy_Data_3
# /Measurement_000/Channel_000/Noisy_Data_4
# /Measurement_000/Channel_000/Noisy_Data_5
# /Measurement_000/Channel_000/Noisy_Data_6
# /Measurement_000/Channel_000/Noisy_Data_7
# /Measurement_000/Channel_000/Noisy_Data_8
# /Measurement_000/Channel_000/Position_Indices
# /Measurement_000/Channel_000/Position_Values
# /Measurement_000/Channel_000/Raw_Data
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Step_Averaged_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Step_Averaged_Response
# /Measurement_000/Channel_000/Spectroscopic_Indices
# /Measurement_000/Channel_000/Spectroscopic_Values
# /Measurement_000/Channel_000/UDVS
# /Measurement_000/Channel_000/UDVS_Indices
# /Noisy_Data_1_SHO_Fit
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Fit
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Guess
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_2_SHO_Fit
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Fit
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Guess
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_3_SHO_Fit
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Fit
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Guess
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_4_SHO_Fit
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Fit
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Guess
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_5_SHO_Fit
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Fit
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Guess
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_6_SHO_Fit
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Fit
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Guess
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_7_SHO_Fit
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Fit
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Guess
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_8_SHO_Fit
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Fit
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Guess
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/completed_guess_positions
# /Raw_Data_SHO_Fit
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Fit
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Guess
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Spectroscopic_Indices
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Spectroscopic_Values
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/completed_fit_positions
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/completed_guess_positions
#
# The main dataset:
# ------------------------------------
# <HDF5 file "data_raw6.h5" (mode r+)>
#
# The ancillary datasets:
# ------------------------------------
# <HDF5 dataset "Position_Indices": shape (3600, 2), type "<u4">
# <HDF5 dataset "Position_Values": shape (3600, 2), type "<f4">
# <HDF5 dataset "Spectroscopic_Indices": shape (4, 63360), type "<u4">
# <HDF5 dataset "Spectroscopic_Values": shape (4, 63360), type "<f4">
#
# Metadata or attributes in a datagroup
# ------------------------------------
# BE_actual_duration_[s] : 0.004
# BE_amplitude_[V] : 1
# BE_auto_smoothing : auto smoothing on
# BE_band_edge_smoothing_[s] : 4832.1
# BE_band_edge_trim : 0.094742
# BE_band_width_[Hz] : 200000
# BE_bins_per_band : 0
# BE_center_frequency_[Hz] : 1310000
# BE_desired_duration_[s] : 0.004
# BE_phase_content : chirp-sinc hybrid
# BE_phase_variation : 1
# BE_points_per_BE_wave : 0
# BE_repeats : 4
# FORC_V_high1_[V] : 1
# FORC_V_high2_[V] : 10
# FORC_V_low1_[V] : -1
# FORC_V_low2_[V] : -10
# FORC_num_of_FORC_cycles : 1
# FORC_num_of_FORC_repeats : 1
# File_MDAQ_version : MDAQ_VS_090915_01
# File_date_and_time : 18-Sep-2015 18:32:14
# File_file_name : SP128_NSO
# File_file_path : C:\Users\Asylum User\Documents\Users\Agar\SP128_NSO\
# File_file_suffix : 99
# IO_AO_amplifier : 10
# IO_AO_range_[V] : +/- 10
# IO_Analog_Input_1 : +/- .1V, FFT
# IO_Analog_Input_2 : off
# IO_Analog_Input_3 : off
# IO_Analog_Input_4 : off
# IO_DAQ_platform : NI 6115
# IO_rate_[Hz] : 4000000
# VS_amplitude_[V] : 16
# VS_cycle_fraction : full
# VS_cycle_phase_shift : 0
# VS_measure_in_field_loops : in and out-of-field
# VS_mode : DC modulation mode
# VS_number_of_cycles : 2
# VS_offset_[V] : 0
# VS_read_voltage_[V] : 0
# VS_set_pulse_amplitude[V] : 0
# VS_set_pulse_duration[s] : 0.002
# VS_step_edge_smoothing_[s] : 0.001
# VS_steps_per_full_cycle : 96
# data_type : BEPSData
# grid_/single : grid
# grid_contact_set_point_[V] : 1
# grid_current_col : 1
# grid_current_row : 1
# grid_cycle_time_[s] : 10
# grid_measuring : 0
# grid_moving : 0
# grid_num_cols : 60
# grid_num_rows : 60
# grid_settle_time_[s] : 0.15
# grid_time_remaining_[h;m;s] : 10
# grid_total_time_[h;m;s] : 10
# grid_transit_set_point_[V] : 0.1
# grid_transit_time_[s] : 0.15
# num_bins : 165
# num_pix : 3600
# num_udvs_steps : 384

# %%
dataset.file
# Out:
# './Data//data_raw6.h5'

# %%
from m3util.util.h5 import find_measurement

# %%
find_measurement(dataset.file, "Noisy_Data_1",group = "Measurement_000/Channel_000")
# Out:
# 'Noisy_Data_1'

# %%
from m3util.util.h5 import find_groups_with_string

# %%
find_groups_with_string(dataset.file, "Noisy_Data_1")
# Out:
# ['/Noisy_Data_1_SHO_Fit', '/Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000']

# %%
find_groups_with_string(dataset.file, "Noisy_Data_2")
# Out:
# ['/Noisy_Data_2_SHO_Fit', '/Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000']

# %%
find_groups_with_string(dataset.file, "Noisy_Data_9")
# Out:
# []

# %%
out2 = [f"Noisy_Data_{i}" for i in np.arange(1,9)]
out2.append("Raw_Data")

for data2 in out2:
    print(data2)
    if find_groups_with_string(dataset.file, data2) != []:
        print(f"Fitting {data2}")
        #dataset.SHO_Fitter(dataset = data2, h5_sho_targ_grp = f"{data2}_SHO_Fit", max_mem=1024*64, max_cores= 20)
    else:
        print(f"{data2} already fit. Skipping...")
# Out:
# Noisy_Data_1
# Fitting Noisy_Data_1
# Noisy_Data_2
# Fitting Noisy_Data_2
# Noisy_Data_3
# Fitting Noisy_Data_3
# Noisy_Data_4
# Fitting Noisy_Data_4
# Noisy_Data_5
# Fitting Noisy_Data_5
# Noisy_Data_6
# Fitting Noisy_Data_6
# Noisy_Data_7
# Fitting Noisy_Data_7
# Noisy_Data_8
# Fitting Noisy_Data_8
# Raw_Data
# Fitting Raw_Data

# %%
import pyUSID as usid
import h5py

# %%
with h5py.File(dataset.file, "r+") as h5_file:

    h5_main = usid.hdf_utils.find_dataset(h5_file, dataset)[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 with h5py.File(dataset.file, "r+") as h5_file:
# ----> 3     h5_main = usid.hdf_utils.find_dataset(h5_file, dataset)[0]
#
# File ~/anaconda3/envs/BEPFM/lib/python3.10/site-packages/pyUSID/io/hdf_utils/simple.py:100, in find_dataset(h5_group, dset_name)
#      97 from ..usi_data import USIDataset
#      99 datasets = list()
# --> 100 for obj in hut.find_dataset(h5_group, dset_name):
#     101     try:
#     102         datasets.append(USIDataset(obj))
#
# File ~/anaconda3/envs/BEPFM/lib/python3.10/site-packages/sidpy/hdf/hdf_utils.py:738, in find_dataset(h5_group, dset_name)
#     736 if not isinstance(h5_group, (h5py.File, h5py.Group)):
#     737     raise TypeError('h5_group should be a h5py.File or h5py.Group object')
# --> 738 dset_name = validate_single_string_arg(dset_name, 'dset_name')
#     740 # print 'Finding all instances of', ds_name
#     741 datasets = []
#
# File ~/anaconda3/envs/BEPFM/lib/python3.10/site-packages/sidpy/base/string_utils.py:224, in validate_single_string_arg(value, name)
#     206 """
#     207 This function is to be used when validating a SINGLE string parameter for a
#     208 function. Trims the provided value.
#    (...)
#     221     Cleaned string value of the parameter
#     222 """
#     223 if not isinstance(value, (str, unicode)):
# --> 224     raise TypeError(name + ' should be a string')
#     225 value = value.strip()
#     226 if len(value) <= 0:
#
# TypeError: dset_name should be a string
